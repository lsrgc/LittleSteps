# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.DataFrame({
    "id": np.arange(0,8),
    "value": np.linspace(-1,1,8)})
df.head()
# Out:
#    id     value
# 0   0 -1.000000
# 1   1 -0.714286
# 2   2 -0.428571
# 3   3 -0.142857
# 4   4  0.142857

# %%
sns.lineplot(df, x= "id", y = "value")
plt.show()
